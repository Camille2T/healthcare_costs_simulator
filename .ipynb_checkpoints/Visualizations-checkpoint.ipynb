# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# %%bash
# ls prepared_data
# Out:
# Book3.xlsx
# Inpatient.csv
# Output_local_basis.csv
# hospitals.csv

# %% [markdown]
# # 1. Visualizations to explain the need to make predictions

# %%
data_shema=pd.read_excel('prepared_data/Book3.xlsx')

# %%
data_shema
# Out:
#                      Unnamed: 0  \
# 0  Aggregated charges available
# 1                 Not available
#
#    Average spending per Medicare patient available  not available
# 0                                             2985             85
# 1                                               39             59

# %%
data_shema.set_index('Unnamed: 0')
# Out:
#                               Average spending per Medicare patient available  \
# Unnamed: 0
# Aggregated charges available                                             2985
# Not available                                                              39
#
#                               not available
# Unnamed: 0
# Aggregated charges available             85
# Not available                            59

# %% [markdown]
# Let's start focusing on the hospitals with the aggregated charges available (first column of our data).

# %%
inpatients=pd.read_csv('prepared_data/Inpatient.csv')

# %% [markdown]
# Because the number of possible diagnostics is very important (more than 500), some diagnostics are only observed in a few number of hospitals. This is due to the fact that some medical conditions are less common than others in particular for Medicare patients (mainly people above 65) and also that the information on the prices is disclosed only if at least 10 Medicare patients' discharges have been observed at this hospital. As a consequence, the number of observed prices is very dependant on the relative size of the hospital. To show this effect, let's plot the number of observed prices compared to the total Medicare discharges at the hospital level.
#
# Let's build a new variable by hospitals: the number of Medicare discharges per hospital.

# %%
first_graph=inpatients.groupby('prov_id').total_discharges.agg(['count','sum'])

# %%
plt.figure(figsize=[8,5]);
plt.scatter(data=first_graph,x='sum',y='count',s=5);
plt.xlabel('Size of the hospital (nb of Medicare discharges)');
plt.ylabel('# of DRGs with data on charges');
plt.title('Number of different DRGs per hospital size');

# %%
second_graph=inpatients.groupby('DRG').total_discharges.agg(['count','sum'])
second_graph.rename(columns={'count':'count_DRG','sum':'sum_DRG'},inplace=True)
second_graph['proportion_hospitals_DRG']=second_graph['count_DRG']/3182
# Out:
#          count   sum
# prov_id
# 10001      156  6886
# 10005       74  2844
# 10006      114  4435
# 10007       16   341
# 10008        3    45
# ...        ...   ...
# 670112       2    83
# 670116       2    58
# 670119       1    16
# 670120       9   137
# 670122       2    42
#
# [3182 rows x 2 columns]

# %% [markdown]
# Let's try to capture the effect of the 10 discharges threshold

# %%
enriched_inpatients=inpatients.merge(first_graph,left_on= 'prov_id', right_index=True)
enriched_inpatients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196325 entries, 0 to 196324
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   DRG                        196325 non-null  object
#  1   prov_id                    196325 non-null  int64
#  2   Provider State             196325 non-null  object
#  3   prov_zip                   196325 non-null  int64
#  4   total_discharges           196325 non-null  int64
#  5   average_covered_charges    196325 non-null  float64
#  6   average_total_payments     196325 non-null  float64
#  7   average_medicare_payments  196325 non-null  float64
#  8   count                      196325 non-null  int64
#  9   sum                        196325 non-null  int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 16.5+ MB

# %%
enriched_inpatients_2=enriched_inpatients.merge(second_graph, left_on='DRG',right_index=True)

# %%
import random

# %%
#Septicemia, 2800,
#Hip, 2000;

inpatients.DRG.value_counts()[100:150]
# Out:
# 388 - G.I. OBSTRUCTION W MCC                                                 602
# 467 - REVISION OF HIP OR KNEE REPLACEMENT W CC                               601
# 493 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT,FEMUR W CC                   600
# 379 - G.I. HEMORRHAGE W/O CC/MCC                                             598
# 684 - RENAL FAILURE W/O CC/MCC                                               595
# 236 - CORONARY BYPASS W/O CARDIAC CATH W/O MCC                               589
# 854 - INFECTIOUS & PARASITIC DISEASES W O.R. PROCEDURE W CC                  585
# 885 - PSYCHOSES                                                              572
# 884 - ORGANIC DISTURBANCES & INTELLECTUAL DISABILITY                         565
# 441 - DISORDERS OF LIVER EXCEPT MALIG,CIRR,ALC HEPA W MCC                    561
# 244 - PERMANENT CARDIAC PACEMAKER IMPLANT W/O CC/MCC                         561
# 445 - DISORDERS OF THE BILIARY TRACT W CC                                    553
# 234 - CORONARY BYPASS W CARDIAC CATH W/O MCC                                 551
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PROCEDURES W MCC                549
# 472 - CERVICAL SPINAL FUSION W CC                                            539
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC                               529
# 074 - CRANIAL & PERIPHERAL NERVE DISORDERS W/O MCC                           526
# 468 - REVISION OF HIP OR KNEE REPLACEMENT W/O CC/MCC                         521
# 442 - DISORDERS OF LIVER EXCEPT MALIG,CIRR,ALC HEPA W CC                     516
# 070 - NONSPECIFIC CEREBROVASCULAR DISORDERS W MCC                            498
# 419 - LAPAROSCOPIC CHOLECYSTECTOMY W/O C.D.E. W/O CC/MCC                     497
# 071 - NONSPECIFIC CEREBROVASCULAR DISORDERS W CC                             482
# 233 - CORONARY BYPASS W CARDIAC CATH W MCC                                   478
# 220 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PROC W/O CARD CATH W CC         470
# 694 - URINARY STONES W/O ESW LITHOTRIPSY W/O MCC                             467
# 149 - DYSEQUILIBRIUM                                                         467
# 164 - MAJOR CHEST PROCEDURES W CC                                            460
# 271 - OTHER MAJOR CARDIOVASCULAR PROCEDURES W CC                             457
# 621 - O.R. PROCEDURES FOR OBESITY W/O CC/MCC                                 457
# 813 - COAGULATION DISORDERS                                                  455
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS W CC         451
# 274 - PERCUTANEOUS INTRACARDIAC PROCEDURES W/O MCC                           440
# 708 - MAJOR MALE PELVIC PROCEDURES W/O CC/MCC                                436
# 004 - TRACH W MV >96 HRS OR PDX EXC FACE, MOUTH & NECK W/O MAJ O.R.          431
# 219 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PROC W/O CARD CATH W MCC        426
# 254 - OTHER VASCULAR PROCEDURES W/O CC/MCC                                   422
# 003 - ECMO OR TRACH W MV >96 HRS OR PDX EXC FACE, MOUTH & NECK W MAJ O.R.    421
# 304 - HYPERTENSION W MCC                                                     419
# 267 - ENDOVASCULAR CARDIAC VALVE REPLACEMENT W/O MCC                         417
# 516 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. PROC W CC                     416
# 303 - ATHEROSCLEROSIS W/O MCC                                                414
# 038 - EXTRACRANIAL PROCEDURES W CC                                           414
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC                                414
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W MCC                          405
# 543 - PATHOLOGICAL FRACTURES & MUSCULOSKELET & CONN TISS MALIG W CC          405
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC                                         391
# 417 - LAPAROSCOPIC CHOLECYSTECTOMY W/O C.D.E. W MCC                          391
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC                                  388
# 163 - MAJOR CHEST PROCEDURES W MCC                                           383
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL CRISIS & COAGUL W CC          381
# Name: DRG, dtype: int64

# %%
list_DRG=[
    #'683 - RENAL FAILURE W CC',
    '871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 HOURS W MCC',
    '392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DISORDERS W/O MCC',
         '481 - HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W CC',
         #'195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC',
         '243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC',
    '432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC',
    #'003 - ECMO OR TRACH W MV >96 HRS OR PDX EXC FACE, MOUTH & NECK W MAJ O.R.'
        ]

list_prov_id=inpatients.prov_id.drop_duplicates()[1:]
list_prov_id
# Out:
# 156        10005
# 230        10006
# 344        10007
# 360        10008
# 363        10011
#            ...
# 196309    670112
# 196311    670116
# 196313    670119
# 196314    670120
# 196323    670122
# Name: prov_id, Length: 3181, dtype: int64

# %%
g=sb.FacetGrid(data=enriched_inpatients_2[enriched_inpatients_2.DRG.isin(list_DRG) & enriched_inpatients_2.prov_id.isin(list_prov_id)  ],
           hue='DRG',
               height=6,
               palette='Set1'
               , legend_out = True,
                hue_order=list_DRG
       )
g.map(plt.scatter,'sum','total_discharges',s=5,alpha=1)

plt.title("Threshold effect: nb of discharges for 5 specific DRGs",
         fontdict = {'fontsize': 14})
plt.xlabel('Nb of discharges of Medicare patients',fontdict= {'fontsize': 13},)
plt.ylabel('Nb of discharges per DRG and hospital',fontdict= {'fontsize': 13},)
plt.xlim([0,8000])
plt.ylim([0,200])


new_labels = ['Septicemia > 96 hours W MCC',
                         'Esophagitis W/O MCC',
                         'Hip & femur procedures except major joint W CC',
              'Permanent cardiac pacearker implant W CC',
                         'Cirrhosis W MCC',
                           ]

a=plt.legend(labels=new_labels,framealpha=1,markerscale=2) ;
a;

#for t, l in zip(g._legend.texts, new_labels): t.set_text(l)

# %%
plt.figure(figsize=[10,5])
plt.scatter(data=enriched_inpatients_2[enriched_inpatients_2.DRG.isin(list_DRG) & enriched_inpatients_2.prov_id.isin(list_prov_id)],
            x='sum',
            y='total_discharges',
            c='DRG',
           cmap='inferno_r',
            s=15
           )
plt.xlim([0,8000])
plt.ylim([0,100])
cbar=plt.colorbar();
cbar.set_label('% of hospitals with observations of the diagnostic')
plt.xlabel('total number of Medicare discharges per hospital')
plt.ylabel('number of discharges per diagnostic and hospital')
plt.title('Threshold effet: number of discharges per diagnostic and hospital in relation to the size of the hospitals (x-axis) and the % of this' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4238             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4239                 colors = mcolors.to_rgba_array(c)
#    4240             except ValueError:
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 185         rgba = _to_rgba_no_colorcycle(c, alpha)
#     186         try:
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     260             return c, c, c, alpha if alpha is not None else 1.
# --> 261         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     262     # tuple color.
#
# ValueError: Invalid RGBA argument: '243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-222-eca9f519ec12> in <module>
#       1 plt.figure(figsize=[10,5])
# ----> 2 plt.scatter(data=enriched_inpatients_2[enriched_inpatients_2.DRG.isin(list_DRG) & enriched_inpatients_2.prov_id.isin(list_prov_id)],
#       3             x='sum',
#       4             y='total_discharges',
#       5             c='DRG',
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1589                 args_and_kwargs.get(label_namer), auto_label)
#    1590
# -> 1591         return func(*new_args, **new_kwargs)
#    1592
#    1593     inner.__doc__ = _add_data_doc(inner.__doc__, replace_names)
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4399
#    4400         c, colors, edgecolors = \
# -> 4401             self._parse_scatter_color_args(
#    4402                 c, edgecolors, kwargs, x.size,
#    4403                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4243                 # Both the mapping *and* the RGBA conversion failed: pretty
#    4244                 # severe failure => one may appreciate a verbose feedback.
# -> 4245                 raise ValueError(
#    4246                     f"'c' argument must be a color, a sequence of colors, or "
#    4247                     f"a sequence of numbers, not {c}")
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not 262         243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC
# 652         243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC
# 759         243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC
# 859         243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC
# 1019        243 - PERMANENT CARDIAC PACEMAKER IMPLANT W CC
#                                ...
# 15958    871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...
# 16022    871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...
# 16070    871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...
# 16098    871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...
# 16163    871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV >96 H...
# Name: DRG, Length: 780, dtype: object

# %% [markdown]
# **1. The inpatient dataset**
#
# - 196325 observations
#
#
# - 3182 providers ie hospitals (3181 avec filtration of DRG with less than 8 different hospitals)
# 301 have 5 observations or less,
# 552 have 10 or less observations
#
#
# - 563 DRG (440 after filtrations)
# 106 have 5 or less observations
# 149 have 10 or less observations
# 256 have 50 or less observations

# %%
temp=pd.read_csv('Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv')
#temp[temp['Provider State']]
temp.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-133-6b4be8a3d13d> in <module>
# ----> 1 temp=pd.read_csv('Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv')
#       2 #temp[temp['Provider State']]
#       3 temp.info()
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv does not exist: 'Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv'

# %%
inpatient=pd.read_csv('Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv',
                      dtype={'Provider Id':str,'Provider Zip Code':str },
                     usecols=['DRG Definition', 'Provider Id','Provider State', 'Provider Zip Code','Hospital Referral Region (HRR) Description',
       'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
       'Average Medicare Payments'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-134-a66b37772e18> in <module>
# ----> 1 inpatient=pd.read_csv('Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv',
#       2                       dtype={'Provider Id':str,'Provider Zip Code':str },
#       3                      usecols=['DRG Definition', 'Provider Id','Provider State', 'Provider Zip Code','Hospital Referral Region (HRR) Description',
#       4        'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
#       5        'Average Medicare Payments'])
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/envs/cap_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv does not exist: 'Data/MEDICARE_PROVIDER_CHARGE_INPATIENT_DRGALL_FY2017.csv'

# %%
inpatient.columns=['DRG', 'prov_id','Provider State','prov_zip','HRR',
       'total_discharges', 'average_covered_charges', 'average_total_payments',
       'average_medicare_payments']

# %%
inpatient.total_discharges.sum()
# Out:
# 7382688

# %%
inpatient.groupby("prov_id").total_discharges.agg(['sum', 'count'])

# %%
#bUild the number of discharges per hospital and in the y axis the % of DRG that are described
